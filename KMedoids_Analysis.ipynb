# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
from tqdm import tqdm

# %%
pop = pd.read_csv('data/pop_music.csv').drop('Unnamed: 0', axis=1)
print(pop.shape)
pop.head()
# Out:
# (36451, 22)
#    acousticness                            artists  danceability  duration_ms  \
# 0         0.465                ['Three Dog Night']         0.629       166707
# 1         0.166  ['Martha Reeves & The Vandellas']         0.417       176573
# 2         0.840                   ['Roberto Luti']         0.526       158387
# 3         0.908                 ['Dionne Warwick']         0.691       179040
# 4         0.908                  ['Johnny Mathis']         0.609       149627
#
#    energy  explicit  instrumentalness  key  liveness  loudness  mode  \
# 0   0.376         0          0.000000    7    0.2350   -13.934     1
# 1   0.753         0          0.000000    9    0.2690   -10.204     0
# 2   0.501         0          0.000000    0    0.1390    -8.088     1
# 3   0.157         0          0.000007    1    0.0898   -13.711     1
# 4   0.380         0          0.001520    5    0.0728   -10.527     1
#
#                                 name  popularity release_date  speechiness  \
# 0                      It Ain't Easy          26   1970-01-01       0.0337
# 1                  I Should Be Proud          33         1970       0.1260
# 2                             Celoso          39   1970-08-28       0.0367
# 3  Raindrops Keep Falling on My Head          36         1970       0.0475
# 4  Raindrops Keep Fallin' On My Head          31   1970-02-25       0.0343
#
#      tempo  valence  year                track_id               artist_id  \
# 0   76.848    0.347  1970  2hKxnhi2Eb3443AQbOnqNl  4FAEZeJcsYYBkNq2D3KGTV
# 1  178.408    0.794  1970  2nxSAQBvF6gDIwZmG6B9nO  1Pe5hlKMCTULjosqZ6KanP
# 2  113.546    0.762  1970  5FD1IZKwXVSL3zGwlNvLoF  33Cme6gMFRML19GrfipNMH
# 3   89.844    0.378  1970  5o5fCEeIGC8igGmbXQZL8Q  2JSjCHK79gdaiPWdKiNUNp
# 4  109.514    0.612  1970  6BZaceyM6nWzq0AUFcaEX1  21LGsW7bziR4Ledx7WZ1Wf
#
#                                                genre  is_pop
# 0  ['album rock', 'art rock', 'blues rock', 'bril...    True
# 1  ['brill building pop', 'classic girl group', '...    True
# 2                                  ['pop romantico']    True
# 3  ['adult standards', 'brill building pop', 'dis...    True
# 4  ['adult standards', 'brill building pop', 'eas...    True

# %% [markdown]
# # Preprocessing #

# %%
# create new data frame with only necessary features for modeling
pop_model = pop.drop(['artists', 'name', 'popularity', 'release_date', 'year', 'artist_id', 'genre', 'is_pop'], axis=1)
pop_model.set_index('track_id', inplace=True)
print(pop_model.shape)
pop_model.head()
# Out:
# (36451, 13)
#                         acousticness  danceability  duration_ms  energy  \
# track_id
# 2hKxnhi2Eb3443AQbOnqNl         0.465         0.629       166707   0.376
# 2nxSAQBvF6gDIwZmG6B9nO         0.166         0.417       176573   0.753
# 5FD1IZKwXVSL3zGwlNvLoF         0.840         0.526       158387   0.501
# 5o5fCEeIGC8igGmbXQZL8Q         0.908         0.691       179040   0.157
# 6BZaceyM6nWzq0AUFcaEX1         0.908         0.609       149627   0.380
#
#                         explicit  instrumentalness  key  liveness  loudness  \
# track_id
# 2hKxnhi2Eb3443AQbOnqNl         0          0.000000    7    0.2350   -13.934
# 2nxSAQBvF6gDIwZmG6B9nO         0          0.000000    9    0.2690   -10.204
# 5FD1IZKwXVSL3zGwlNvLoF         0          0.000000    0    0.1390    -8.088
# 5o5fCEeIGC8igGmbXQZL8Q         0          0.000007    1    0.0898   -13.711
# 6BZaceyM6nWzq0AUFcaEX1         0          0.001520    5    0.0728   -10.527
#
#                         mode  speechiness    tempo  valence
# track_id
# 2hKxnhi2Eb3443AQbOnqNl     1       0.0337   76.848    0.347
# 2nxSAQBvF6gDIwZmG6B9nO     0       0.1260  178.408    0.794
# 5FD1IZKwXVSL3zGwlNvLoF     1       0.0367  113.546    0.762
# 5o5fCEeIGC8igGmbXQZL8Q     1       0.0475   89.844    0.378
# 6BZaceyM6nWzq0AUFcaEX1     1       0.0343  109.514    0.612

# %%
# create list for different types of features for access later
num_features = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness',
                'speechiness', 'tempo', 'valence']
cat_features = ['explicit', 'mode', 'key']

# %% [markdown]
# ### Using Gower Distance ###

# %% [markdown]
# Because the data contains a mixture of both numerical and categorical features, we will be using Gower Distance to calculate the similarity between two observations. Gower distance is on the range of 0 (identical) to 1 (maximally different). This will be very useful for including the categorical variables in the model.

# %%
import gower

# %%
# return the top 10 songs that are most similar to 'Hollaback Girl' by Gwen Stefani
sd = gower.gower_topn(pop_model.iloc[18544:18545,:], pop_model.iloc[:,:], n = 10)

# print the mean values for the features for these tracks
print(pop_model.iloc[sd['index']].describe().loc[['mean']])
# DataFrame that lists the names of these tracks
pop.iloc[sd['index']]
# Out:
#       acousticness  danceability  duration_ms  energy  explicit  \
# mean       0.24402        0.8669     225546.3    0.82       1.0
#
#       instrumentalness   key  liveness  loudness  mode  speechiness     tempo  \
# mean          0.000019  10.1   0.08532   -3.9557   0.0      0.14992  103.8573
#
#       valence
# mean   0.8087
#        acousticness                                            artists  \
# 18544        0.3500                                   ['Gwen Stefani']
# 18440        0.2060                                          ['Nelly']
# 15065        0.2900                    ['Clipse', 'Pharrell Williams']
# 25487        0.3040                                     ['A$AP Rocky']
# 19088        0.0960                          ['Travis Porter', 'Tyga']
# 6281         0.2510                ['Pharrell Williams', 'Kanye West']
# 24790        0.3510                                            ['DMX']
# 4902         0.2950                                          ['Logic']
# 28733        0.2330                               ['Lil Jon', 'LMFAO']
# 21536        0.0642  ['Calvin Harris', 'Pharrell Williams', 'Katy P...
#
#        danceability  duration_ms  energy  explicit  instrumentalness  key  \
# 18544         0.926       199853   0.916         1          0.000006   10
# 18440         0.956       228240   0.745         1          0.000000   11
# 15065         0.705       261213   0.837         1          0.000000   10
# 25487         0.897       187105   0.743         1          0.000044   10
# 19088         0.905       211293   0.782         1          0.000000   10
# 6281          0.845       236573   0.801         1          0.000000   10
# 24790         0.904       244013   0.728         1          0.000137   10
# 4902          0.762       213013   0.919         1          0.000000    9
# 28733         0.876       250747   0.984         1          0.000000   10
# 21536         0.893       223413   0.745         1          0.000000   11
#
#        liveness  loudness  mode  \
# 18544    0.0234    -2.221     0
# 18440    0.0615    -4.753     0
# 15065    0.0571    -4.640     0
# 25487    0.1370    -5.446     0
# 19088    0.0623    -3.604     0
# 6281     0.0951    -5.619     0
# 24790    0.1460    -4.773     0
# 4902     0.1260    -3.378     0
# 28733    0.0505    -2.018     0
# 21536    0.0943    -3.105     0
#
#                                                     name  popularity  \
# 18544                                     Hollaback Girl          68
# 18440                                       Hot In Herre          72
# 15065                 I'm Good (feat. Pharrell Williams)          42
# 25487                                       Babushka Boi          74
# 19088                            Ayy Ladies (feat. Tyga)          71
# 6281                                          Number One          48
# 24790                                How's It Goin' Down          54
# 4902                                                 Now          52
# 28733                                    Outta Your Mind          56
# 21536  Feels (feat. Pharrell Williams, Katy Perry & B...          77
#
#       release_date  speechiness    tempo  valence  year  \
# 18544   2004-11-23       0.0929  110.007    0.904  2004
# 18440   2002-06-25       0.1200  107.075    0.912  2002
# 15065   2009-12-08       0.0962   82.022    0.938  2009
# 25487   2019-08-28       0.2220  134.979    0.905  2019
# 19088   2012-05-28       0.1640   96.055    0.798  2012
# 6281    2006-01-01       0.1290  107.012    0.666  2006
# 24790   2007-06-12       0.2750   90.458    0.847  2007
# 4902    2014-10-21       0.0690  109.971    0.603  2014
# 28733   2010-01-01       0.2740   99.976    0.642  2010
# 21536   2017-06-30       0.0571  101.018    0.872  2017
#
#                      track_id               artist_id  \
# 18544  0LzrhCZFXW94Y8nwtTuRlw  4yiQZ8tQPux8cPriYMWUFP
# 18440  04KTF78FFg8sOHC1BADqbY  2gBjLmx6zQnFGQJCAQpRgw
# 15065  4dna9pp213lAcnSrbj3xGn  2J257euzcjnDLipsyJH3F2
# 25487  643PW82aBMUa1FiWi5VQY7  13ubrt8QOOCPljQ2FL1Kca
# 19088  4P6BuLsqtg5uISdE77ypI9  6z1cicLMt9XArxN10q7m8a
# 6281   3r4U9UpHaFurMtq1oCZoAp  2RdwBSPQiwcmiDo9kixcl8
# 24790  4tkSJRlbhuVxYjvuIQaMcj  1HwM5zlC5qNWhJtM00yXzG
# 4902   4iEWnkDewJ72copeODWuOw  4xRYI6VqpkE3UwrDrAZL8L
# 28733  1Oenqmtbzt331Pgv0ODfS2  7sfl4Xt5KmfyDs2T3SVSMK
# 21536  5bcTCxgc7xVfSaMV3RuVke  7CajNmpbOovFoOoasH2HaY
#
#                                                    genre  is_pop
# 18544  ['dance pop', 'europop', 'hip pop', 'pop', 'po...    True
# 18440  ['dance pop', 'hip hop', 'pop', 'pop rap', 'ra...    True
# 15065  ['alternative hip hop', 'gangster rap', 'hardc...    True
# 25487  ['east coast hip hop', 'hip hop', 'pop rap', '...    True
# 19088  ['atl hip hop', 'dirty south rap', 'pop rap', ...    True
# 6281                                  ['pop', 'pop rap']    True
# 24790  ['east coast hip hop', 'gangster rap', 'hardco...    True
# 4902   ['conscious hip hop', 'dmv rap', 'hip hop', 'p...    True
# 28733  ['atl hip hop', 'crunk', 'dance pop', 'dirty s...    True
# 21536  ['dance pop', 'edm', 'electro house', 'house',...    True

# %%
# return the top 10 songs that are most similar to 'Electric Feel' by MGMT
sd = gower.gower_topn(pop_model.iloc[18717:18718,:], pop_model.iloc[:,:], n = 10)

# print the mean values for the features for these tracks
print(pop_model.iloc[sd['index']].describe().loc[['mean']])
# DataFrame that lists the names of these tracks
pop.iloc[sd['index']]
# Out:
#       acousticness  danceability  duration_ms  energy  explicit  \
# mean      0.032594        0.7479     242834.3    0.75       0.0
#
#       instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# mean           0.11365  0.9    0.3143   -6.6027   1.0      0.04879  101.484
#
#       valence
# mean   0.5964
#        acousticness                                          artists  \
# 18717      0.071400                                         ['MGMT']
# 27056      0.015400                                ['Ariana Grande']
# 27224      0.014700                                ['Glass Animals']
# 21131      0.030800                   ['Hot Chelle Rae', 'New Boyz']
# 2853       0.050200                                    ['Lady Gaga']
# 18209      0.020200                                    ['Sugar Ray']
# 26634      0.023500                                    ['Sugar Ray']
# 24131      0.081400                                        ['SNAP!']
# 6909       0.000245  ['Ed Sheeran', 'Chris Stapleton', 'Bruno Mars']
# 23123      0.018100                       ['Justin Bieber', 'Jaden']
#
#        danceability  duration_ms  energy  explicit  instrumentalness  key  \
# 18717         0.763       229640   0.807         0          0.280000    1
# 27056         0.725       197600   0.796         0          0.000000    1
# 27224         0.699       281407   0.670         0          0.220000    1
# 21131         0.742       188200   0.784         0          0.000000    1
# 2853          0.752       263360   0.840         0          0.000001    1
# 18209         0.835       244640   0.648         0          0.225000    1
# 26634         0.836       244560   0.644         0          0.194000    1
# 24131         0.757       341963   0.708         0          0.206000    1
# 6909          0.631       209120   0.796         0          0.011500    1
# 23123         0.739       227853   0.807         0          0.000000    0
#
#        liveness  loudness  mode                                      name  \
# 18717     0.348    -3.714     1                             Electric Feel
# 27056     0.354    -3.684     1                                    Baby I
# 27224     0.356    -6.219     1                               Life Itself
# 21131     0.354    -5.458     1      I Like It Like That (feat. New Boyz)
# 2853      0.227    -5.047     1                             Paper Gangsta
# 18209     0.308    -8.150     1                                       Fly
# 26634     0.297    -8.110     1                                       Fly
# 24131     0.224   -15.232     1                   The Power - 12" Version
# 6909      0.380    -5.350     1  BLOW (with Chris Stapleton & Bruno Mars)
# 23123     0.295    -5.063     1                           Never Say Never
#
#        popularity release_date  speechiness    tempo  valence  year  \
# 18717          78   2007-12-14       0.0350  103.038    0.559  2007
# 27056          56   2013-01-01       0.0326  101.976    0.517  2013
# 27224          63   2016-08-26       0.0347  111.988    0.556  2016
# 21131          65   2011-11-25       0.0552  101.002    0.650  2011
# 2853           46   2008-01-01       0.0786   98.969    0.574  2008
# 18209          65   1997-06-20       0.0488   99.701    0.674  1997
# 26634          52   2005-12-20       0.0522   99.721    0.652  2005
# 24131          52         1990       0.0455  108.928    0.554  1990
# 6909           69   2019-07-05       0.0401   92.469    0.596  2019
# 23123          69   2011-01-01       0.0652   97.048    0.632  2011
#
#                      track_id               artist_id  \
# 18717  3FtYbEfBqAlGO46NUDQSAt  0SwO7SWeDHJijQ3XNS7xEE
# 27056  6EIsMa5lbvljYxqCkjZVDi  66CXWjxzNUsdJxJ2JdwvnR
# 27224  32zkKx35Et6A515oZKxDkD  4yvcSjfu4PC0CYQyLy4wSq
# 21131  6eFahAdQgABBj1XOM99cBG  6jTnHxhb6cDCaCu4rdvsQ0
# 2853   0LtZYj18X8mpZ2M6A7nA8t  1HY2Jd0NmPuamShAr6KMms
# 18209  3uPfVXcjnpOjyzI3jb3js4  4uN3DsfENc7dp0OLO0FEIb
# 26634  5fuGP7Dze9tkadS9WoPbar  4uN3DsfENc7dp0OLO0FEIb
# 24131  0c4s0e7Wi7EOzfjr7XNIwz  2FrKQPjJe4pVMZOgm0ESOx
# 6909   6EbduYTr62sSzvl36wWiFM  6eUKZXaKkcviH0Ku9w2n3V
# 23123  5GYbkDveRD2I8M5ZJ14hWn  1uNFoZAHBGtllmzznpCI3s
#
#                                                    genre  is_pop
# 18717  ['alternative dance', 'indie pop', 'indie rock...    True
# 27056              ['dance pop', 'pop', 'post-teen pop']    True
# 27224  ['gauze pop', 'indietronica', 'modern rock', '...    True
# 21131  ['dance pop', 'neo mellow', 'neon pop punk', '...    True
# 2853                                ['dance pop', 'pop']    True
# 18209  ['alternative metal', 'alternative rock', 'fun...    True
# 26634  ['alternative metal', 'alternative rock', 'fun...    True
# 24131  ['diva house', 'eurodance', 'europop', 'german...    True
# 6909                                   ['pop', 'uk pop']    True
# 23123           ['canadian pop', 'pop', 'post-teen pop']    True

# %% [markdown]
# After verifying these results by listening to the tracks, gower distance is a good measure of distance to use.

# %% [markdown]
# ### Calcuate Matrix of Similarities Between All Tracks ###

# %%
# create a list of cat_features indicators
cat_ind = [True if x in cat_features else False for x in pop_model.columns]

gdf = gower.gower_matrix(pop_model, cat_features=cat_ind)

# %%
gdf_model = pd.DataFrame(gdf, index=pop_model.index)
print(gdf_model.shape)
gdf_model.head()
# Out:
# (36451, 36451)
#                            0         1         2         3         4      \
# track_id
# 2hKxnhi2Eb3443AQbOnqNl  0.000000  0.318137  0.190260  0.154133  0.166769
# 2nxSAQBvF6gDIwZmG6B9nO  0.318137  0.000000  0.285791  0.376135  0.322953
# 5FD1IZKwXVSL3zGwlNvLoF  0.190260  0.285791  0.000000  0.177559  0.121840
# 5o5fCEeIGC8igGmbXQZL8Q  0.154133  0.376135  0.177559  0.000000  0.136289
# 6BZaceyM6nWzq0AUFcaEX1  0.166769  0.322953  0.121840  0.136289  0.000000
#
#                            5         6         7         8         9      \
# track_id
# 2hKxnhi2Eb3443AQbOnqNl  0.181071  0.200302  0.182654  0.285563  0.178499
# 2nxSAQBvF6gDIwZmG6B9nO  0.262695  0.359025  0.297781  0.197825  0.213617
# 5FD1IZKwXVSL3zGwlNvLoF  0.151540  0.183514  0.050899  0.260644  0.214327
# 5o5fCEeIGC8igGmbXQZL8Q  0.217068  0.145480  0.157355  0.266697  0.236650
# 6BZaceyM6nWzq0AUFcaEX1  0.171277  0.089381  0.125636  0.249391  0.216901
#
#                            10        11        12        13        14     \
# track_id
# 2hKxnhi2Eb3443AQbOnqNl  0.179381  0.099288  0.247378  0.211589  0.275625
# 2nxSAQBvF6gDIwZmG6B9nO  0.214328  0.322283  0.216653  0.280581  0.234321
# 5FD1IZKwXVSL3zGwlNvLoF  0.191458  0.122024  0.232669  0.245654  0.198692
# 5o5fCEeIGC8igGmbXQZL8Q  0.229464  0.152851  0.258652  0.222938  0.261645
# 6BZaceyM6nWzq0AUFcaEX1  0.210000  0.107462  0.237270  0.229925  0.218925
#
#                            15        16        17        18        19     \
# track_id
# 2hKxnhi2Eb3443AQbOnqNl  0.105691  0.150809  0.245769  0.269703  0.133423
# 2nxSAQBvF6gDIwZmG6B9nO  0.268567  0.222398  0.296164  0.280324  0.267091
# 5FD1IZKwXVSL3zGwlNvLoF  0.207400  0.199922  0.272331  0.270165  0.150099
# 5o5fCEeIGC8igGmbXQZL8Q  0.237329  0.193632  0.215215  0.235955  0.190081
# 6BZaceyM6nWzq0AUFcaEX1  0.199799  0.189995  0.252812  0.186970  0.168858
#
#                            20        21        22        23        24     ...  \
# track_id                                                                  ...
# 2hKxnhi2Eb3443AQbOnqNl  0.167526  0.140402  0.220700  0.204026  0.139491  ...
# 2nxSAQBvF6gDIwZmG6B9nO  0.307812  0.276694  0.361751  0.230545  0.420548  ...
# 5FD1IZKwXVSL3zGwlNvLoF  0.183621  0.191044  0.213177  0.072795  0.238350  ...
# 5o5fCEeIGC8igGmbXQZL8Q  0.111255  0.185194  0.175165  0.236647  0.166942  ...
# 6BZaceyM6nWzq0AUFcaEX1  0.144752  0.107802  0.192878  0.181544  0.207853  ...
#
#                            36426     36427     36428     36429     36430  \
# track_id
# 2hKxnhi2Eb3443AQbOnqNl  0.219884  0.119930  0.145708  0.201619  0.172243
# 2nxSAQBvF6gDIwZmG6B9nO  0.231186  0.335621  0.297543  0.384401  0.268204
# 5FD1IZKwXVSL3zGwlNvLoF  0.205210  0.206402  0.187215  0.166264  0.186243
# 5o5fCEeIGC8igGmbXQZL8Q  0.259546  0.154454  0.172679  0.237689  0.130795
# 6BZaceyM6nWzq0AUFcaEX1  0.222117  0.172853  0.167104  0.224464  0.180992
#
#                            36431     36432     36433     36434     36435  \
# track_id
# 2hKxnhi2Eb3443AQbOnqNl  0.167616  0.364336  0.316340  0.330993  0.399585
# 2nxSAQBvF6gDIwZmG6B9nO  0.338057  0.255465  0.193491  0.291956  0.233176
# 5FD1IZKwXVSL3zGwlNvLoF  0.194684  0.336977  0.201502  0.337658  0.362718
# 5o5fCEeIGC8igGmbXQZL8Q  0.215111  0.389808  0.341288  0.362838  0.434126
# 6BZaceyM6nWzq0AUFcaEX1  0.206575  0.347236  0.299211  0.339936  0.393707
#
#                            36436     36437     36438     36439     36440  \
# track_id
# 2hKxnhi2Eb3443AQbOnqNl  0.184455  0.248420  0.364312  0.310168  0.317192
# 2nxSAQBvF6gDIwZmG6B9nO  0.249471  0.214301  0.270365  0.370385  0.356578
# 5FD1IZKwXVSL3zGwlNvLoF  0.207924  0.101529  0.387745  0.299675  0.337173
# 5o5fCEeIGC8igGmbXQZL8Q  0.225895  0.251881  0.413174  0.258192  0.317121
# 6BZaceyM6nWzq0AUFcaEX1  0.208910  0.195790  0.406034  0.297222  0.322903
#
#                            36441     36442     36443     36444     36445  \
# track_id
# 2hKxnhi2Eb3443AQbOnqNl  0.278278  0.157054  0.134117  0.417235  0.187655
# 2nxSAQBvF6gDIwZmG6B9nO  0.187212  0.305455  0.217161  0.258285  0.261984
# 5FD1IZKwXVSL3zGwlNvLoF  0.280025  0.114712  0.235124  0.384617  0.200402
# 5o5fCEeIGC8igGmbXQZL8Q  0.312380  0.197843  0.247111  0.378224  0.223334
# 6BZaceyM6nWzq0AUFcaEX1  0.279194  0.180270  0.230234  0.415719  0.203587
#
#                            36446     36447     36448     36449     36450
# track_id
# 2hKxnhi2Eb3443AQbOnqNl  0.254883  0.259855  0.087099  0.192624  0.144887
# 2nxSAQBvF6gDIwZmG6B9nO  0.296490  0.362888  0.295891  0.251158  0.292260
# 5FD1IZKwXVSL3zGwlNvLoF  0.376386  0.230142  0.166541  0.212572  0.113681
# 5o5fCEeIGC8igGmbXQZL8Q  0.366739  0.302505  0.195651  0.170708  0.194413
# 6BZaceyM6nWzq0AUFcaEX1  0.377900  0.302954  0.178595  0.220434  0.191961
#
# [5 rows x 36451 columns]

# %% [markdown]
# The result is a matrix of similarity values for all tracks in the original dataframe. This will be used to cluster the tracks. Clustering was done in another notebook on Google Cloud for the added memory and processing power. The modeling process can be found in the KMedoids_Models notebook.

# %% [markdown]
# # Modeling Analysis #

# %% [markdown]
# Below are the results of the best model from the KMedoids_Models notebook.

# %%
import pickle 
results = pickle.load(open("data/model_results.p", "rb"))
results
# Out:
# {'k': array([3, 1, 3, ..., 3, 2, 3]),
#  'medoids': [33715, 31645, 25321, 16834],
#  'v_ratio': 10483.229974915155,
#  's_score': 0.22875765}
