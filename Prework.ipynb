# %% [markdown]
# # Project Pre-work #

# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
from tqdm import tqdm

# %%
# data frame all tracks with features from 1921-2020
tracks = pd.read_csv('data/data.csv')
print(tracks.shape)
tracks.head()
# Out:
# (169909, 19)
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# 1    8    0.0763   -28.454     1
# 2    5    0.1190   -19.924     0
# 3    1    0.1110   -14.734     0
# 4   11    0.0980   -16.829     1
#
#                                             name  popularity release_date  \
# 0                    Singende Bataillone 1. Teil           0         1928
# 1       Fantasiestücke, Op. 111: Più tosto lento           0         1928
# 2                 Chapter 1.18 - Zamek kaniowski           0         1928
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0   1928-09-25
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1         1928
#
#    speechiness    tempo  valence  year
# 0       0.0506  118.469   0.7790  1928
# 1       0.0462   83.972   0.0767  1928
# 2       0.9290  107.177   0.8800  1928
# 3       0.0926  108.003   0.7200  1928
# 4       0.0424   62.149   0.0693  1928

# %%
# data frame containing the list of all unique genres according to Spotify and their average feature values
genres = pd.read_csv('data/genres.csv')
print(genres.shape)
genres.head()
# Out:
# (2664, 14)
#            genres  acousticness  danceability   duration_ms    energy  \
# 0           432hz      0.494780      0.299333  1.048887e+06  0.450678
# 1              []      0.679245      0.521473  2.298526e+05  0.401522
# 2      a cappella      0.621532      0.577017  1.936522e+05  0.345694
# 3        abstract      0.359395      0.459500  3.430185e+05  0.487000
# 4  abstract beats      0.353347      0.694400  2.338244e+05  0.613400
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.477762  0.131000 -16.854000     0.076817  120.285667  0.221750
# 1          0.196737  0.221586 -12.679076     0.112267  112.025168  0.515920
# 2          0.003799  0.127087 -12.770211     0.095324  111.813230  0.453186
# 3          0.791400  0.119480 -14.092000     0.043420  124.743200  0.304990
# 4          0.349403  0.102453  -6.699800     0.143453  119.398400  0.634187
#
#    popularity  key  mode
# 0   52.166667    5     1
# 1   21.682005    7     1
# 2   43.351819   11     1
# 3   41.500000    1     1
# 4   58.600000   10     0

# %% [markdown]
# ## Genres Exploration ##

# %% [markdown]
# The `genres` serves a sources/list of the names of every genre Spotify has data on. I want to start by extracting all the subgenres of *pop* from the `genres`. This list will then be used to filter out `tracks` to only include tracks that fall under *pop* music.

# %%
# 2664 unique genres in total
genres_list = list(genres.genres)
print(len(genres_list))
genres_list
# Out:
# 2664
# ['432hz',
#  '[]',
#  'a cappella',
#  'abstract',
#  'abstract beats',
#  'abstract hip hop',
#  'accordeon',
#  'accordion',
#  'acid house',
#  'acid jazz',
#  'acid rock',
#  'acid trance',
#  'acousmatic',
#  'acoustic blues',
#  'acoustic pop',
#  'acoustic punk',
#  'adoracion',
#  'adult standards',
#  'adventista',
#  'afghan pop',
#  'african gospel',
#  'african percussion',
#  'african reggae',
#  'african rock',
#  'afro dancehall',
#  'afro house',
#  'afro psych',
#  'afro-cuban traditional',
#  'afro-funk',
#  'afrobeat',
#  'afrobeat brasileiro',
#  'afrofuturism',
#  'afrofuturismo brasileiro',
#  'afropop',
#  'afroswing',
#  'aggrotech',
#  'alabama indie',
#  'alabama metal',
#  'alabama rap',
#  'albanian pop',
#  'alberta country',
#  'alberta hip hop',
#  'album rock',
#  'albuquerque indie',
#  'alt-idol',
#  'alternative americana',
#  'alternative country',
#  'alternative dance',
#  'alternative emo',
#  'alternative hip hop',
#  'alternative metal',
#  'alternative pop',
#  'alternative pop rock',
#  'alternative r&b',
#  'alternative rock',
#  'alternative roots rock',
#  'ambeat',
#  'ambient',
#  'ambient black metal',
#  'ambient folk',
#  'ambient house',
#  'ambient idm',
#  'ambient pop',
#  'ambient techno',
#  'ambient worship',
#  'american choir',
#  'american contemporary classical',
#  'american folk revival',
#  'american metalcore',
#  'american modern classical',
#  'american post-rock',
#  'american primitive',
#  'american romanticism',
#  'american shoegaze',
#  'anadolu rock',
#  'anarcho-punk',
#  'andean',
#  'anglican liturgy',
#  'animal singing',
#  'anime',
#  'anime latino',
#  'anime rock',
#  'anime score',
#  'ann arbor indie',
#  'anthem emo',
#  'anthem worship',
#  'anti-folk',
#  'antilliaanse folklore',
#  'antiviral pop',
#  'appalachian folk',
#  'arab folk',
#  'arab groove',
#  'arab pop',
#  'arab trap',
#  'arabesk',
#  'arabic hip hop',
#  'arabic jazz',
#  'argentine ambient',
#  'argentine hardcore',
#  'argentine heavy metal',
#  'argentine hip hop',
#  'argentine indie',
#  'argentine metal',
#  'argentine punk',
#  'argentine reggae',
#  'argentine rock',
#  'arkansas country',
#  'arkansas indie',
#  'armenian folk',
#  'art pop',
#  'art punk',
#  'art rock',
#  'asbury park indie',
#  'asian american hip hop',
#  'asmr',
#  'athens indie',
#  'atl hip hop',
#  'atl trap',
#  'atlanta indie',
#  'atmosphere',
#  'atmospheric black metal',
#  'atmospheric dnb',
#  'atmospheric post-metal',
#  'atmospheric post-rock',
#  'atmospheric sludge',
#  'auckland indie',
#  'audiophile vocal',
#  'aussietronica',
#  'austin americana',
#  'austin hip hop',
#  'austin singer-songwriter',
#  'austindie',
#  'australian alternative pop',
#  'australian alternative rock',
#  "australian children's music",
#  'australian choir',
#  'australian country',
#  'australian dance',
#  'australian electropop',
#  'australian garage punk',
#  'australian hip hop',
#  'australian house',
#  'australian indie',
#  'australian indie folk',
#  'australian indie rock',
#  'australian indigenous',
#  'australian metal',
#  'australian metalcore',
#  'australian pop',
#  'australian post-hardcore',
#  'australian post-punk',
#  'australian psych',
#  'australian r&b',
#  'australian reggae fusion',
#  'australian rock',
#  'australian singer-songwriter',
#  'australian ska',
#  'australian talent show',
#  'australian trap',
#  'australian underground hip hop',
#  'austrian choir',
#  'austrian pop',
#  'austro-german modernism',
#  'autoharp',
#  'autonomous black metal',
#  'avant-garde',
#  'avant-garde jazz',
#  'avant-garde metal',
#  'axe',
#  'azeri traditional',
#  'azonto',
#  'azontobeats',
#  'bachata',
#  'background music',
#  'bahamian folk',
#  'bahamian pop',
#  'baiao',
#  'baile pop',
#  'bakersfield sound',
#  'balearic',
#  'balkan brass',
#  'ballet class',
#  'ballroom',
#  'baltic classical',
#  'baltimore hip hop',
#  'baltimore indie',
#  'banda',
#  'banda caliente',
#  'banda carnavalera',
#  'bandinhas',
#  'bandoneon',
#  'bangla',
#  'banjo',
#  'bansuri',
#  'barbadian pop',
#  'barbershop',
#  'bard',
#  'barnmusik',
#  'baroque',
#  'baroque ensemble',
#  'baroque pop',
#  'baroque singing',
#  'baroque violin',
#  'bass house',
#  'bass music',
#  'bass trap',
#  'basshall',
#  'bassline',
#  'bath indie',
#  'baton rouge indie',
#  'baton rouge rap',
#  'battle rap',
#  'bay area hip hop',
#  'bay area indie',
#  'bboy',
#  'bc underground hip hop',
#  'beach music',
#  'beat italiano',
#  'beat poetry',
#  'beatboxing',
#  'beatlesque',
#  'bebop',
#  'bedroom pop',
#  'bedroom soul',
#  'belarusian indie',
#  'belarusian pop',
#  'belarusian rock',
#  'belgian contemporary classical',
#  'belgian dance',
#  'belgian edm',
#  'belgian indie',
#  'belgian indie rock',
#  'belgian jazz',
#  'belgian new wave',
#  'belgian pop',
#  'belgian rock',
#  'belgian singer-songwriter',
#  'belly dance',
#  'bengali folk',
#  'beninese pop',
#  'bergen indie',
#  'berlin school',
#  'bhangra',
#  'big band',
#  'big beat',
#  'big room',
#  'binaural',
#  'birmingham grime',
#  'birmingham hip hop',
#  'birmingham metal',
#  'bitpop',
#  "black 'n' roll",
#  'black comedy',
#  'black metal',
#  'black thrash',
#  'blackened crust',
#  'blackgaze',
#  'bleep techno',
#  'bluegrass',
#  'bluegrass gospel',
#  'blues',
#  'blues latinoamericano',
#  'blues rock',
#  'bmore',
#  'bohemian baroque',
#  'bolero',
#  'bolero cubano',
#  'boogaloo',
#  'boogie',
#  'boogie-woogie',
#  'boom bap',
#  'bossa nova',
#  'bossa nova jazz',
#  'boston hardcore',
#  'boston hip hop',
#  'boston indie',
#  'boston metal',
#  'boston punk',
#  'boston rock',
#  'bounce',
#  'bouncy house',
#  'bouzouki',
#  'bow pop',
#  'boy band',
#  'boy pop',
#  'boy soprano',
#  'brain waves',
#  'braindance',
#  'brass band',
#  'brass ensemble',
#  'brass quintet',
#  'brazilian boogie',
#  'brazilian composition',
#  'brazilian edm',
#  'brazilian hip hop',
#  'brazilian indie',
#  'brazilian jazz',
#  'brazilian metal',
#  'brazilian modern jazz',
#  'brazilian percussion',
#  'brazilian psychedelic',
#  'brazilian punk',
#  'brazilian punk rock',
#  'brazilian reggae',
#  'brazilian rock',
#  'brazilian ska',
#  'brazilian soul',
#  'brazilian thrash metal',
#  'breakbeat',
#  'breakcore',
#  'brega',
#  'breton folk',
#  'brighton indie',
#  'brill building pop',
#  'brisbane indie',
#  'bristol electronic',
#  'bristol indie',
#  'brit funk',
#  'british alternative rock',
#  'british black metal',
#  'british blues',
#  'british brass band',
#  "british children's music",
#  'british choir',
#  'british comedy',
#  'british contemporary classical',
#  'british dance band',
#  'british experimental',
#  'british folk',
#  'british indie rock',
#  'british industrial',
#  'british invasion',
#  'british jazz',
#  'british modern classical',
#  'british post-rock',
#  'british singer-songwriter',
#  'british soul',
#  'british soundtrack',
#  'britpop',
#  'broadway',
#  'broken beat',
#  'bronx hip hop',
#  'brooklyn indie',
#  'brostep',
#  'brutal death metal',
#  'brutal deathcore',
#  'bubble trance',
#  'bubblegum dance',
#  'bubblegum pop',
#  'buffalo ny indie',
#  'buffalo ny metal',
#  'bulgarian folk',
#  'burmese traditional',
#  'bush ballad',
#  'c-pop',
#  'c86',
#  'cabaret',
#  'cajun',
#  'calgary indie',
#  'cali rap',
#  'calming instrumental',
#  'calypso',
#  'cambodian rock',
#  'cambridge choir',
#  'cambridgeshire indie',
#  'canadian americana',
#  'canadian blues',
#  'canadian ccm',
#  'canadian celtic',
#  "canadian children's music",
#  'canadian choir',
#  'canadian classical',
#  'canadian comedy',
#  'canadian contemporary country',
#  'canadian contemporary r&b',
#  'canadian country',
#  'canadian electronic',
#  'canadian electropop',
#  'canadian experimental',
#  'canadian folk',
#  'canadian hardcore',
#  'canadian hip hop',
#  'canadian house',
#  'canadian indie',
#  'canadian indie folk',
#  'canadian indigenous',
#  'canadian latin',
#  'canadian metal',
#  'canadian metalcore',
#  'canadian modern jazz',
#  'canadian pop',
#  'canadian pop punk',
#  'canadian post-hardcore',
#  'canadian post-rock',
#  'canadian psychedelic',
#  'canadian punk',
#  'canadian rock',
#  'canadian rockabilly',
#  'canadian singer-songwriter',
#  'canadian soundtrack',
#  'cancion infantil mexicana',
#  'cancion melodica',
#  'candomble',
#  'candy pop',
#  'cantautor',
#  'cante flamenco',
#  'canterbury scene',
#  'canto popular uruguayo',
#  'cantopop',
#  "canzone d'autore",
#  'canzone genovese',
#  'canzone napoletana',
#  'cape breton folk',
#  'cape town indie',
#  'cape verdean folk',
#  'carnatic',
#  'carnatic instrumental',
#  'carnatic vocal',
#  'cartoon',
#  'cathedral choir',
#  'catstep',
#  'ccm',
#  'cedm',
#  'cello',
#  'celtic',
#  'celtic harp',
#  'celtic metal',
#  'celtic punk',
#  'celtic rock',
#  'cha-cha-cha',
#  'chakra',
#  'chamber choir',
#  'chamber ensemble',
#  'chamber folk',
#  'chamber orchestra',
#  'chamber pop',
#  'chamber psych',
#  'champeta',
#  'channel islands indie',
#  'channel pop',
#  'chanson',
#  'chanson paillarde',
#  'chaotic hardcore',
#  'charanga',
#  'charlotte nc indie',
#  'charlottesville indie',
#  'chattanooga indie',
#  'chicago blues',
#  'chicago drill',
#  'chicago hardcore',
#  'chicago house',
#  'chicago indie',
#  'chicago pop punk',
#  'chicago punk',
#  'chicago rap',
#  'chicago soul',
#  'chicano punk',
#  'chicano rap',
#  'chicha',
#  'chihuahua indie',
#  "children's choir",
#  "children's folk",
#  "children's music",
#  "children's story",
#  'chilean hardcore',
#  'chilean indie',
#  'chilean rock',
#  'chill beats',
#  'chill guitar',
#  'chill lounge',
#  'chillhop',
#  'chillstep',
#  'chillwave',
#  'chinese audiophile',
#  'chinese classical',
#  'chinese classical performance',
#  'chinese electropop',
#  'chinese folk',
#  'chinese hip hop',
#  'chinese idol pop',
#  'chinese indie',
#  'chinese indie rock',
#  'chinese instrumental',
#  'chinese jazz',
#  'chinese soundtrack',
#  'chinese traditional',
#  'chiptune',
#  'chopped and screwed',
#  'choral',
#  'choro',
#  'christchurch indie',
#  'christian a cappella',
#  'christian alternative rock',
#  'christian dance',
#  'christian hard rock',
#  'christian hardcore',
#  'christian hip hop',
#  'christian indie',
#  'christian metal',
#  'christian music',
#  'christian pop',
#  'christian power metal',
#  'christian punk',
#  'christian relaxative',
#  'christian rock',
#  'christian trap',
#  'christian uplift',
#  'christmas instrumental',
#  'chunchaca',
#  'chutney',
#  'cincinnati indie',
#  'cinematic post-rock',
#  'circuit',
#  'circus',
#  'classic afrobeat',
#  'classic arab pop',
#  'classic australian country',
#  'classic belgian pop',
#  'classic bollywood',
#  'classic canadian rock',
#  'classic cantopop',
#  'classic colombian pop',
#  'classic country pop',
#  'classic czech pop',
#  'classic danish pop',
#  'classic eurovision',
#  'classic finnish pop',
#  'classic finnish rock',
#  'classic french pop',
#  'classic garage rock',
#  'classic girl group',
#  'classic greek pop',
#  'classic hardstyle',
#  'classic icelandic pop',
#  'classic iskelma',
#  'classic israeli pop',
#  'classic italian folk pop',
#  'classic italian pop',
#  'classic j-rock',
#  'classic japanese jazz',
#  'classic korean pop',
#  'classic mandopop',
#  'classic norwegian pop',
#  'classic opm',
#  'classic pakistani pop',
#  'classic persian pop',
#  'classic peruvian pop',
#  'classic polish pop',
#  'classic praise',
#  'classic progressive house',
#  'classic psychedelic rock',
#  'classic rock',
#  'classic russian pop',
#  'classic russian rock',
#  'classic schlager',
#  'classic soul',
#  'classic soundtrack',
#  'classic swedish pop',
#  'classic thai pop',
#  'classic turkish pop',
#  'classic uk pop',
#  'classic venezuelan pop',
#  'classical',
#  'classical accordion',
#  'classical baritone',
#  'classical bass',
#  'classical cello',
#  'classical clarinet',
#  'classical contralto',
#  'classical countertenor',
#  'classical era',
#  'classical flute',
#  'classical guitar',
#  'classical guitar quartet',
#  'classical harp',
#  'classical horn',
#  'classical mandolin',
#  'classical mezzo-soprano',
#  'classical oboe',
#  'classical organ',
#  'classical performance',
#  'classical piano',
#  'classical piano duo',
#  'classical piano trio',
#  'classical saxophone',
#  'classical soprano',
#  'classical tenor',
#  'classical trumpet',
#  'classify',
#  'clawhammer banjo',
#  'clean comedy',
#  'coco',
#  'collage pop',
#  'college a cappella',
#  'college marching band',
#  'colombian hip hop',
#  'colombian pop',
#  'colombian rock',
#  'columbus ohio indie',
#  'comedienne',
#  'comedy',
#  'comedy rap',
#  'comedy rock',
#  'comic',
#  'comic metal',
#  'complextro',
#  'compositional ambient',
#  'concepcion indie',
#  'concert band',
#  'concertina',
#  'connecticut hardcore',
#  'connecticut indie',
#  'conscious hip hop',
#  'contemporary classical',
#  'contemporary classical piano',
#  'contemporary country',
#  'contemporary folk',
#  'contemporary gospel',
#  'contemporary jazz',
#  'contemporary post-bop',
#  'contemporary vocal jazz',
#  'contrabass',
#  'cook islands pop',
#  'cool jazz',
#  'copla',
#  'cornwall indie',
#  'corrido',
#  'corridos tumbados',
#  'corrosion',
#  'cosmic american',
#  'cosmic post-rock',
#  'country',
#  'country blues',
#  'country boogie',
#  'country dawn',
#  'country gospel',
#  'country pop',
#  'country rap',
#  'country road',
#  'country rock',
#  'coverchill',
#  'cowboy western',
#  'cowpunk',
#  'crack rock steady',
#  'croatian folk',
#  'croatian pop',
#  'croatian rock',
#  'crossover thrash',
#  'crunk',
#  'crust punk',
#  'cuarteto',
#  'cuatro venezolano',
#  'cuban alternative',
#  'cuban rumba',
#  'cubaton',
#  'cumbia',
#  'cumbia andina mexicana',
#  'cumbia chilena',
#  'cumbia ecuatoriana',
#  'cumbia funk',
#  'cumbia lagunera',
#  'cumbia paraguaya',
#  'cumbia peruana',
#  'cumbia pop',
#  'cumbia ranchera',
#  'cumbia salvadorena',
#  'cumbia santafesina',
#  'cumbia sonidera',
#  'cumbia villera',
#  'cyberpunk',
#  'cymraeg',
#  'cypriot pop',
#  'czech contemporary classical',
#  'czech folk',
#  'czech hip hop',
#  'czech rock',
#  'czsk hip hop',
#  'd-beat',
#  'dabke',
#  'dakke dak',
#  'dallas indie',
#  'dance pop',
#  'dance rock',
#  'dance-punk',
#  'dancehall',
#  'dangdut',
#  'danish classical',
#  'danish electronic',
#  'danish electropop',
#  'danish hip hop',
#  'danish jazz',
#  'danish metal',
#  'danish pop',
#  'danish pop rock',
#  'danish post-punk',
#  'danish rock',
#  'danish singer-songwriter',
#  'dansband',
#  'danseband',
#  'dansktop',
#  'danspunk',
#  'dark cabaret',
#  'dark disco',
#  'dark jazz',
#  'dark post-punk',
#  'dark techno',
#  'dark trap',
#  'dark wave',
#  'darksynth',
#  'dayton indie',
#  'dc hardcore',
#  'dc indie',
#  "death 'n' roll",
#  'death metal',
#  'deathcore',
#  'deathgrass',
#  'deathgrind',
#  'deathrash',
#  'deathrock',
#  'deathstep',
#  'deep acoustic pop',
#  'deep adult standards',
#  'deep big room',
#  'deep ccm',
#  'deep christian rock',
#  'deep classic garage rock',
#  'deep comedy',
#  'deep contemporary country',
#  'deep cumbia sonidera',
#  'deep dance pop',
#  'deep delta blues',
#  'deep disco',
#  'deep disco house',
#  'deep dnb',
#  'deep east coast hip hop',
#  'deep euro house',
#  'deep free jazz',
#  'deep freestyle',
#  'deep funk',
#  'deep g funk',
#  'deep gothic post-punk',
#  'deep groove house',
#  'deep house',
#  'deep idm',
#  'deep indian pop',
#  'deep indie singer-songwriter',
#  'deep latin alternative',
#  'deep latin christian',
#  'deep melodic euro house',
#  'deep melodic metalcore',
#  'deep minimal techno',
#  'deep motown',
#  'deep new americana',
#  'deep new wave',
#  'deep norteno',
#  'deep northern soul',
#  'deep pop edm',
#  'deep pop r&b',
#  'deep psychobilly',
#  'deep punk rock',
#  'deep r&b',
#  'deep ragga',
#  'deep regional mexican',
#  'deep smooth jazz',
#  'deep soft rock',
#  'deep soul house',
#  'deep soundtrack',
#  'deep southern soul',
#  'deep southern trap',
#  'deep talent show',
#  'deep tech house',
#  'deep tropical house',
#  'deep underground hip hop',
#  'deep uplifting trance',
#  'delta blues',
#  'dembow',
#  'denpa-kei',
#  'denton tx indie',
#  'denver indie',
#  'derby indie',
#  'desert blues',
#  'desi hip hop',
#  'desi pop',
#  'destroy techno',
#  'detroit hip hop',
#  'detroit house',
#  'detroit techno',
#  'detroit trap',
#  'detske pisnicky',
#  'detskie pesni',
#  'devon indie',
#  'dfw rap',
#  'dhrupad',
#  'digital hardcore',
#  'dinner jazz',
#  'dirty south rap',
#  'dirty texas rap',
#  'disco',
#  'disco house',
#  'disney',
#  'diva house',
#  'dixieland',
#  'diy emo',
#  'djent',
#  'dmv rap',
#  'dominican pop',
#  'dong-yo',
#  'doo-wop',
#  'doom metal',
#  'doujin',
#  'downtempo',
#  'drama',
#  'dream pop',
#  'dream trance',
#  'dreamgaze',
#  'dreamo',
#  'drift',
#  'drill',
#  'drill and bass',
#  'drone',
#  'drone ambient',
#  'drone folk',
#  'drone metal',
#  'drum and bass',
#  'dub',
#  'dub metal',
#  'dub poetry',
#  'dub techno',
#  'dubstep',
#  'duduk',
#  'duluth indie',
#  'dunedin indie',
#  'dunedin sound',
#  'dungeon synth',
#  'duranguense',
#  'dusseldorf electronic',
#  'dutch blues',
#  'dutch cabaret',
#  'dutch death metal',
#  'dutch edm',
#  'dutch folk',
#  'dutch hip hop',
#  'dutch house',
#  'dutch indie',
#  'dutch jazz',
#  'dutch metal',
#  'dutch pop',
#  'dutch prog',
#  'dutch rock',
#  'dutch trance',
#  'dutch trap pop',
#  'e6fi',
#  'early avant garde',
#  'early modern classical',
#  'early music',
#  'early music choir',
#  'early music ensemble',
#  'early reggae',
#  'early romantic era',
#  'early synthpop',
#  'early us punk',
#  'east coast hip hop',
#  'east coast reggae',
#  'eastern bloc groove',
#  'easy listening',
#  'easycore',
#  'eau claire indie',
#  'ebm',
#  'ecm-style jazz',
#  'ectofolk',
#  'ecuadorian pop',
#  'edm',
#  'edmonton indie',
#  'egyptian pop',
#  'egyptian traditional',
#  'el paso indie',
#  'electra',
#  'electric bass',
#  'electric blues',
#  'electro',
#  'electro house',
#  'electro jazz',
#  'electro latino',
#  'electro swing',
#  'electro-industrial',
#  'electroclash',
#  'electrofox',
#  'electronic djent',
#  'electronic rock',
#  'electronic trap',
#  'electronica',
#  'electronica argentina',
#  'electropop',
#  'electropowerpop',
#  'emo',
#  'emo punk',
#  'emo rap',
#  'emocore',
#  'english baroque',
#  'english indie rock',
#  'english renaissance',
#  'enka',
#  'entehno',
#  'environmental',
#  'epic doom',
#  'epicore',
#  'erhu',
#  'escape room',
#  'esperanto',
#  'essex indie',
#  'estonian hip hop',
#  'estonian pop',
#  'ethereal wave',
#  'etherpop',
#  'ethio-jazz',
#  'ethiopian pop',
#  'ethnomusicology',
#  'euphoric hardstyle',
#  'eurobeat',
#  'eurodance',
#  'europop',
#  'euroska',
#  'eurovision',
#  'exotica',
#  'experimental',
#  'experimental ambient',
#  'experimental big band',
#  'experimental folk',
#  'experimental hip hop',
#  'experimental house',
#  'experimental jazz',
#  'experimental poetry',
#  'experimental pop',
#  'experimental rock',
#  'experimental vocal',
#  'fado',
#  'family gospel',
#  'faroese pop',
#  'fast melodic punk',
#  'fidget house',
#  'fijian pop',
#  'filmi',
#  'filter house',
#  'filthstep',
#  'final fantasy',
#  'fingerstyle',
#  'finnish alternative rock',
#  'finnish classical',
#  'finnish contemporary classical',
#  'finnish death metal',
#  'finnish edm',
#  'finnish hard rock',
#  'finnish metal',
#  'finnish power metal',
#  'finnish soul',
#  'flamenco',
#  'flamenco guitar',
#  'flick hop',
#  'float house',
#  'florida death metal',
#  'florida rap',
#  'fluxwork',
#  'fo jing',
#  'focus',
#  'focus beats',
#  'folclor afrocolombiano',
#  'folclor colombiano',
#  'folclore extremeno',
#  'folclore navarra',
#  'folk',
#  'folk metal',
#  'folk punk',
#  'folk rock',
#  'folk rock italiano',
#  'folk-pop',
#  'folklore argentino',
#  'folklore ecuatoriano',
#  'folklore peruano',
#  'folklore venezolano',
#  'folkmusik',
#  'folktronica',
#  'footwork',
#  'forro',
#  'forro tradicional',
#  'fort worth indie',
#  'fourth world',
#  'francoton',
#  'frankfurt electronic',
#  'freak folk',
#  'freakbeat',
#  'free folk',
#  'free improvisation',
#  'free jazz',
#  'freestyle',
#  'fremantle indie',
#  'french baroque',
#  'french death metal',
#  'french hip hop',
#  'french indie pop',
#  'french indietronica',
#  ...]

# %%
# extract all subgenres a pop
pop_genres = [g for g in genres_list if 'pop' in g]

# %%
# 275 subgenres of pop
print(len(pop_genres))
pop_genres
# Out:
# 275
# ['acoustic pop',
#  'afghan pop',
#  'afropop',
#  'albanian pop',
#  'alternative pop',
#  'alternative pop rock',
#  'ambient pop',
#  'antiviral pop',
#  'arab pop',
#  'art pop',
#  'australian alternative pop',
#  'australian electropop',
#  'australian pop',
#  'austrian pop',
#  'bahamian pop',
#  'baile pop',
#  'barbadian pop',
#  'baroque pop',
#  'bedroom pop',
#  'belarusian pop',
#  'belgian pop',
#  'beninese pop',
#  'bitpop',
#  'bow pop',
#  'boy pop',
#  'brill building pop',
#  'britpop',
#  'bubblegum pop',
#  'c-pop',
#  'canadian electropop',
#  'canadian pop',
#  'canadian pop punk',
#  'candy pop',
#  'canto popular uruguayo',
#  'cantopop',
#  'chamber pop',
#  'channel pop',
#  'chicago pop punk',
#  'chinese electropop',
#  'chinese idol pop',
#  'christian pop',
#  'classic arab pop',
#  'classic belgian pop',
#  'classic cantopop',
#  'classic colombian pop',
#  'classic country pop',
#  'classic czech pop',
#  'classic danish pop',
#  'classic finnish pop',
#  'classic french pop',
#  'classic greek pop',
#  'classic icelandic pop',
#  'classic israeli pop',
#  'classic italian folk pop',
#  'classic italian pop',
#  'classic korean pop',
#  'classic mandopop',
#  'classic norwegian pop',
#  'classic pakistani pop',
#  'classic persian pop',
#  'classic peruvian pop',
#  'classic polish pop',
#  'classic russian pop',
#  'classic swedish pop',
#  'classic thai pop',
#  'classic turkish pop',
#  'classic uk pop',
#  'classic venezuelan pop',
#  'collage pop',
#  'colombian pop',
#  'cook islands pop',
#  'country pop',
#  'croatian pop',
#  'cumbia pop',
#  'cypriot pop',
#  'dance pop',
#  'danish electropop',
#  'danish pop',
#  'danish pop rock',
#  'deep acoustic pop',
#  'deep dance pop',
#  'deep indian pop',
#  'deep pop edm',
#  'deep pop r&b',
#  'desi pop',
#  'dominican pop',
#  'dream pop',
#  'dutch pop',
#  'dutch trap pop',
#  'early synthpop',
#  'ecuadorian pop',
#  'egyptian pop',
#  'electropop',
#  'electropowerpop',
#  'estonian pop',
#  'etherpop',
#  'ethiopian pop',
#  'europop',
#  'experimental pop',
#  'faroese pop',
#  'fijian pop',
#  'folk-pop',
#  'french indie pop',
#  'french pop',
#  'futurepop',
#  'gabonese pop',
#  'garage pop',
#  'gauze pop',
#  'german pop',
#  'german pop rock',
#  'glitch pop',
#  'greek pop',
#  'grunge pop',
#  'guatemalan pop',
#  'guinean pop',
#  'hip pop',
#  'hmong pop',
#  'hokkien pop',
#  'hyperpop',
#  'icelandic pop',
#  'ilocano pop',
#  'indie cafe pop',
#  'indie dream pop',
#  'indie electropop',
#  'indie pop',
#  'indie pop rap',
#  'indie poptimism',
#  'indie psych-pop',
#  'indonesian pop',
#  'iraqi pop',
#  'irish pop',
#  'israeli pop',
#  'italian arena pop',
#  'italian pop',
#  'italian pop rock',
#  'j-pop',
#  'j-pop girl group',
#  'j-poprock',
#  'jangle pop',
#  'japanese city pop',
#  'japanese dream pop',
#  'japanese electropop',
#  'japanese pop punk',
#  'jordanian pop',
#  'k-pop',
#  'k-pop boy group',
#  'k-pop girl group',
#  'kashmiri pop',
#  'korean pop',
#  'la pop',
#  'latin arena pop',
#  'latin pop',
#  'latin viral pop',
#  'lebanese pop',
#  'mainland chinese pop',
#  'malaysian mandopop',
#  'malaysian pop',
#  'mande pop',
#  'mandopop',
#  'marathi pop',
#  'metropopolis',
#  'mexican pop',
#  'mexican pop punk',
#  'modern dream pop',
#  'modern jangle pop',
#  'modern power pop',
#  'moldovan pop',
#  'mongolian pop',
#  'moroccan pop',
#  'musica popular paraense',
#  'muzica populara',
#  'nederpop',
#  'neo-synthpop',
#  'neon pop punk',
#  'nepali pop',
#  'new wave pop',
#  'nigerian pop',
#  'noise pop',
#  'norwegian pop',
#  'norwegian pop rap',
#  'nyc pop',
#  'nz pop',
#  'okinawan pop',
#  'operatic pop',
#  'pakistani pop',
#  'palestinian pop',
#  'panamanian pop',
#  'persian pop',
#  'pinoy pop punk',
#  'polish pop',
#  'polynesian pop',
#  'pop',
#  'pop argentino',
#  'pop catracho',
#  'pop chileno',
#  'pop edm',
#  'pop emo',
#  'pop folk',
#  'pop house',
#  'pop nacional',
#  'pop peruano',
#  'pop punk',
#  'pop quebecois',
#  'pop rap',
#  'pop reggaeton',
#  'pop rock',
#  'pop romantico',
#  'pop urbaine',
#  'pop violin',
#  'popgaze',
#  'popping',
#  'popwave',
#  'post-teen pop',
#  'power pop',
#  'power-pop punk',
#  'psychedelic pop',
#  'puerto rican pop',
#  'punjabi pop',
#  'regional mexican pop',
#  'romanian pop',
#  'russian pop',
#  'scandipop',
#  'sertanejo pop',
#  'shimmer pop',
#  'shiver pop',
#  'singaporean mandopop',
#  'singaporean pop',
#  'slovak pop',
#  'socal pop punk',
#  'social media pop',
#  'soda pop',
#  'south african pop',
#  'soviet synthpop',
#  'space age pop',
#  'spanish indie pop',
#  'spanish pop',
#  'spanish pop rock',
#  'stomp pop',
#  'sudanese pop',
#  'sunshine pop',
#  'swamp pop',
#  'swedish electropop',
#  'swedish idol pop',
#  'swedish indie pop',
#  'swedish pop',
#  'swedish synthpop',
#  'swiss pop',
#  'synthpop',
#  'syrian pop',
#  'taiwan pop',
#  'tajik pop',
#  'tamil pop',
#  'teen pop',
#  'texas pop punk',
#  'thai indie pop',
#  'thai pop',
#  'transpop',
#  'turkish pop',
#  'turkish trap pop',
#  'twee pop',
#  'ugandan pop',
#  'uk alternative pop',
#  'uk pop',
#  'uk pop punk',
#  'ukrainian pop',
#  'underground power pop',
#  'v-pop',
#  'vapor pop',
#  'vietnamese pop',
#  'vintage chinese pop',
#  'vintage dutch pop',
#  'vintage italian pop',
#  'vintage spanish pop',
#  'vintage swedish pop',
#  'viral pop']

# %% [markdown]
# There are 275 subgenres of *pop* music. Interestingly, however, a lot of these subgenres are descriptors of locations like 'german electropop.' It takes the subgenre and further divides it according to region. I wonder if it worth being this granular? Should I stop differentiating at a certain point? How can I decide when to do this?

# %% [markdown]
# ## Track Data Exploration ##

# %%
# start by narrowing tracks from the last 50 years (1970-2020)
df = tracks[tracks.year >= 1970]
print(df.shape)
df.head()
# Out:
# (101656, 19)
#       acousticness                            artists  danceability  \
# 3054         0.511                     ['Elton John']         0.436
# 3055         0.465                ['Three Dog Night']         0.629
# 3056         0.166  ['Martha Reeves & The Vandellas']         0.417
# 3057         0.990                  ['Vashti Bunyan']         0.600
# 3058         0.639                      ['Ry Cooder']         0.568
#
#       duration_ms  energy  explicit                      id  instrumentalness  \
# 3054       380667   0.429         0  2AgMTn4RyRrI1uc3iXx4Xq          0.000103
# 3055       166707   0.376         0  2hKxnhi2Eb3443AQbOnqNl          0.000000
# 3056       176573   0.753         0  2nxSAQBvF6gDIwZmG6B9nO          0.000000
# 3057       141893   0.107         0  2vNuzzaFEPY2WGdYFhdeui          0.011400
# 3058       134067   0.434         0  439kdOcVhEp5gQ67eYNkKG          0.626000
#
#       key  liveness  loudness  mode                   name  popularity  \
# 3054    3     0.104   -10.884     1        My Father's Gun          29
# 3055    7     0.235   -13.934     1          It Ain't Easy          26
# 3056    9     0.269   -10.204     0      I Should Be Proud          33
# 3057    0     0.101   -19.189     0  Where I Like To Stand          26
# 3058    7     0.229   -14.170     1        Available Space          35
#
#      release_date  speechiness    tempo  valence  year
# 3054   1970-10-30       0.0319  119.025    0.223  1970
# 3055   1970-01-01       0.0337   76.848    0.347  1970
# 3056         1970       0.1260  178.408    0.794  1970
# 3057         1970       0.0525  117.630    0.732  1970
# 3058   1970-01-01       0.0379  147.388    0.694  1970

# %% [markdown]
# `tracks` does not list the genre of each track. In order to get genre for each track I would have to make an API call to Spotify since genres are only listed as 'Artist' data. Each artist has a list of tracks that are associated with them. If I then merge those genres for a given track, how do I decided the primary genre of that track?

# %% [markdown]
# ## Grabbing Genre Data ##

# %% [markdown]
# ### Practice ###

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# api credentials
spotify_creds = SpotifyClientCredentials(client_id='d81a95eae1b9423385df789736549e80', 
                                         client_secret='fdfc7d6877fc485a8ce5be3f2ab2e056')

# instatiate call object
sp = spotipy.Spotify(client_credentials_manager=spotify_creds)

# %%
# I can only make 50 calls at a time so I'm going to need to find a way to iterate in chunks of 50
track_ids = list(df.id)

# %% [markdown]
# **Get Artists IDs from Track IDs**

# %%
# track data for first 50 tracks
first_50 = track_ids[0:50]
test_call = sp.tracks(first_50, market='US')

# %%
# how to extract artist id from track results
test_call['tracks'][49]['artists'][0]['id']
# Out:
# '22bE4uQ6baNwSHPVcDxLCe'

# %%
# list of artist ids corresponding to each track
test_artists = []
for i in range(len(test_call['tracks'])):
    test_artists.append(test_call['tracks'][i]['artists'][0]['id'])

# %% [markdown]
# **Get Genres from Track IDs**

# %%
# artist data for first 50 tracks
test_call2 = sp.artists(test_artists)

# %%
# how to extract genres from artist results
test_call2['artists'][0]['genres']
# Out:
# ['glam rock', 'mellow gold', 'piano rock', 'soft rock']

# %%
# list of genres for each artist
test_genres = []
for i in range(len(test_call2['artists'])):
    test_genres.append(test_call2['artists'][i]['genres'])

# %% [markdown]
# **Create DataFrame that contains TrackID, ArtistID, Genres**

# %%
test_dict = {'track_id' : first_50,
             'artist_id': test_artists,
             'genres' : test_genres}
pd.DataFrame(test_dict).head()
# Out:
#                  track_id               artist_id  \
# 0  2AgMTn4RyRrI1uc3iXx4Xq  3PhoLpVuITZKcymswpck5b
# 1  2hKxnhi2Eb3443AQbOnqNl  4FAEZeJcsYYBkNq2D3KGTV
# 2  2nxSAQBvF6gDIwZmG6B9nO  1Pe5hlKMCTULjosqZ6KanP
# 3  2vNuzzaFEPY2WGdYFhdeui  4chuPfKtATDZvbRLExsTp2
# 4  439kdOcVhEp5gQ67eYNkKG  1CPwHx5lgVxv0rfcp7UXLx
#
#                                               genres
# 0    [glam rock, mellow gold, piano rock, soft rock]
# 1  [album rock, art rock, blues rock, brill build...
# 2  [brill building pop, classic girl group, class...
# 3  [anti-folk, british folk, folk, freak folk, ne...
# 4  [blues, blues rock, country blues, country roc...

# %% [markdown]
# ### Building the Genre DataFrame ###

# %%
# divide track_ids list into chunks of 50
id_chunks = [track_ids[x:x+50] for x in range(0, len(track_ids), 50)]

# %%
# get artist ids for all tracks
artist_ids = []
for x in tqdm(range(len(id_chunks))):
    results = sp.tracks(id_chunks[x], market='US')
    for i in range(len(results['tracks'])):
        artist_ids.append(results['tracks'][i]['artists'][0]['id'])
# Out:
# 100%|██████████| 2034/2034 [03:19<00:00, 10.19it/s]

# %%
# divide artist_ids into chunks of 50
artist_chunks = [artist_ids[x:x+50] for x in range(0, len(artist_ids), 50)]

# %%
# get genres for all artist
genres = []
for x in tqdm(range(len(artist_chunks))):
    results = sp.artists(artist_chunks[x])
    for i in range(len(results['artists'])):
        genres.append(results['artists'][i]['genres'])
# Out:
# 100%|██████████| 2034/2034 [03:17<00:00, 10.28it/s]

# %%
# turn fetched info into dataframe to be merged with original
genre_dict = {'track_id' : track_ids,
              'artist_id' : artist_ids,
              'genre' : genres}
genre_df = pd.DataFrame(genre_dict)

# %%
print(genre_df.shape)
genre_df.head()
# Out:
# (101656, 3)
#                  track_id               artist_id  \
# 0  2AgMTn4RyRrI1uc3iXx4Xq  3PhoLpVuITZKcymswpck5b
# 1  2hKxnhi2Eb3443AQbOnqNl  4FAEZeJcsYYBkNq2D3KGTV
# 2  2nxSAQBvF6gDIwZmG6B9nO  1Pe5hlKMCTULjosqZ6KanP
# 3  2vNuzzaFEPY2WGdYFhdeui  4chuPfKtATDZvbRLExsTp2
# 4  439kdOcVhEp5gQ67eYNkKG  1CPwHx5lgVxv0rfcp7UXLx
#
#                                                genre
# 0    [glam rock, mellow gold, piano rock, soft rock]
# 1  [album rock, art rock, blues rock, brill build...
# 2  [brill building pop, classic girl group, class...
# 3  [anti-folk, british folk, folk, freak folk, ne...
# 4  [blues, blues rock, country blues, country roc...

# %%
df_final = df.merge(genre_df, how='left', left_on='id', right_on='track_id')
df_final.drop('id', axis=1, inplace=True)
df_final.head()
# Out:
#    acousticness                            artists  danceability  duration_ms  \
# 0         0.511                     ['Elton John']         0.436       380667
# 1         0.465                ['Three Dog Night']         0.629       166707
# 2         0.166  ['Martha Reeves & The Vandellas']         0.417       176573
# 3         0.990                  ['Vashti Bunyan']         0.600       141893
# 4         0.639                      ['Ry Cooder']         0.568       134067
#
#    energy  explicit  instrumentalness  key  liveness  loudness  mode  \
# 0   0.429         0          0.000103    3     0.104   -10.884     1
# 1   0.376         0          0.000000    7     0.235   -13.934     1
# 2   0.753         0          0.000000    9     0.269   -10.204     0
# 3   0.107         0          0.011400    0     0.101   -19.189     0
# 4   0.434         0          0.626000    7     0.229   -14.170     1
#
#                     name  popularity release_date  speechiness    tempo  \
# 0        My Father's Gun          29   1970-10-30       0.0319  119.025
# 1          It Ain't Easy          26   1970-01-01       0.0337   76.848
# 2      I Should Be Proud          33         1970       0.1260  178.408
# 3  Where I Like To Stand          26         1970       0.0525  117.630
# 4        Available Space          35   1970-01-01       0.0379  147.388
#
#    valence  year                track_id               artist_id  \
# 0    0.223  1970  2AgMTn4RyRrI1uc3iXx4Xq  3PhoLpVuITZKcymswpck5b
# 1    0.347  1970  2hKxnhi2Eb3443AQbOnqNl  4FAEZeJcsYYBkNq2D3KGTV
# 2    0.794  1970  2nxSAQBvF6gDIwZmG6B9nO  1Pe5hlKMCTULjosqZ6KanP
# 3    0.732  1970  2vNuzzaFEPY2WGdYFhdeui  4chuPfKtATDZvbRLExsTp2
# 4    0.694  1970  439kdOcVhEp5gQ67eYNkKG  1CPwHx5lgVxv0rfcp7UXLx
#
#                                                genre
# 0    [glam rock, mellow gold, piano rock, soft rock]
# 1  [album rock, art rock, blues rock, brill build...
# 2  [brill building pop, classic girl group, class...
# 3  [anti-folk, british folk, folk, freak folk, ne...
# 4  [blues, blues rock, country blues, country roc...

# %% [markdown]
# ## Cleaning Up the DataFrame ##

# %% [markdown]
# Now that we have a the genre associated for each artist of each track, we want to create a dataframe that only include tracks that are a subgenre of pop.

# %%
# create a function that returns true if a pop sub_genre is contained in a track's genre list
def is_pop(g_list):
    return any(item in g_list for item in pop_genres)

# %%
# apply function
df_final['is_pop'] = df_final['genre'].apply(is_pop)

# %%
df_final
# Out:
#         acousticness                             artists  danceability  \
# 0             0.5110                      ['Elton John']         0.436
# 1             0.4650                 ['Three Dog Night']         0.629
# 2             0.1660   ['Martha Reeves & The Vandellas']         0.417
# 3             0.9900                   ['Vashti Bunyan']         0.600
# 4             0.6390                       ['Ry Cooder']         0.568
# ...              ...                                 ...           ...
# 101651        0.1730              ['DripReport', 'Tyga']         0.875
# 101652        0.0167  ['Leon Bridges', 'Terrace Martin']         0.719
# 101653        0.5380               ['Kygo', 'Oh Wonder']         0.514
# 101654        0.0714       ['Cash Cash', 'Andy Grammer']         0.646
# 101655        0.1090                  ['Ingrid Andress']         0.512
#
#         duration_ms  energy  explicit  instrumentalness  key  liveness  \
# 0            380667   0.429         0          0.000103    3    0.1040
# 1            166707   0.376         0          0.000000    7    0.2350
# 2            176573   0.753         0          0.000000    9    0.2690
# 3            141893   0.107         0          0.011400    0    0.1010
# 4            134067   0.434         0          0.626000    7    0.2290
# ...             ...     ...       ...               ...  ...       ...
# 101651       163800   0.443         1          0.000032    1    0.0891
# 101652       167468   0.385         0          0.031300    8    0.1110
# 101653       180700   0.539         0          0.002330    7    0.1080
# 101654       167308   0.761         0          0.000000    1    0.2220
# 101655       214787   0.428         0          0.000000    0    0.1050
#
#         loudness  mode                            name  popularity  \
# 0        -10.884     1                 My Father's Gun          29
# 1        -13.934     1                   It Ain't Easy          26
# 2        -10.204     0               I Should Be Proud          33
# 3        -19.189     0           Where I Like To Stand          26
# 4        -14.170     1                 Available Space          35
# ...          ...   ...                             ...         ...
# 101651    -7.461     1   Skechers (feat. Tyga) - Remix          75
# 101652   -10.907     1  Sweeter (feat. Terrace Martin)          64
# 101653    -9.332     1                How Would I Know          70
# 101654    -2.557     1                     I Found You          70
# 101655    -7.387     1           More Hearts Than Mine          65
#
#        release_date  speechiness    tempo  valence  year  \
# 0        1970-10-30       0.0319  119.025    0.223  1970
# 1        1970-01-01       0.0337   76.848    0.347  1970
# 2              1970       0.1260  178.408    0.794  1970
# 3              1970       0.0525  117.630    0.732  1970
# 4        1970-01-01       0.0379  147.388    0.694  1970
# ...             ...          ...      ...      ...   ...
# 101651   2020-05-15       0.1430  100.012    0.306  2020
# 101652   2020-06-08       0.0403  128.000    0.270  2020
# 101653   2020-05-29       0.1050  123.700    0.153  2020
# 101654   2020-02-28       0.0385  129.916    0.472  2020
# 101655   2020-03-27       0.0271   80.588    0.366  2020
#
#                       track_id               artist_id  \
# 0       2AgMTn4RyRrI1uc3iXx4Xq  3PhoLpVuITZKcymswpck5b
# 1       2hKxnhi2Eb3443AQbOnqNl  4FAEZeJcsYYBkNq2D3KGTV
# 2       2nxSAQBvF6gDIwZmG6B9nO  1Pe5hlKMCTULjosqZ6KanP
# 3       2vNuzzaFEPY2WGdYFhdeui  4chuPfKtATDZvbRLExsTp2
# 4       439kdOcVhEp5gQ67eYNkKG  1CPwHx5lgVxv0rfcp7UXLx
# ...                        ...                     ...
# 101651  4KppkflX7I3vJQk7urOJaS  3O5HD95HTEPgoPFOjAb7yV
# 101652  1ehhGlTvjtHo2e4xJFB0SZ  3qnGvpP8Yth1AqSBMqON5x
# 101653  52eycxprLhK3lPcRLbQiVk  23fqKkggKUBHNkbKtXEls4
# 101654  3wYOGJYD31sLRmBgCvWxa4  1LOB7jTeEV14pHai6EXSzF
# 101655  60RFlt48hm0l4Fu0JoccOl  0jPnVIasXzBYjrlpO5irii
#
#                                                     genre  is_pop
# 0         [glam rock, mellow gold, piano rock, soft rock]   False
# 1       [album rock, art rock, blues rock, brill build...    True
# 2       [brill building pop, classic girl group, class...    True
# 3       [anti-folk, british folk, folk, freak folk, ne...   False
# 4       [blues, blues rock, country blues, country roc...   False
# ...                                                   ...     ...
# 101651                                        [viral rap]   False
# 101652                               [modern blues, soul]   False
# 101653                         [edm, pop, tropical house]    True
# 101654  [big room, dance pop, edm, electro house, elec...    True
# 101655                [contemporary country, country pop]    True
#
# [101656 rows x 22 columns]

# %%
pop_df = df_final[df_final.is_pop == True]
print(pop_df.shape)
pop_df.tail()
# Out:
# (36451, 22)
#         acousticness                          artists  danceability  \
# 101648        0.2640     ['Meek Mill', 'Roddy Ricch']         0.744
# 101649        0.0227  ['Trey Songz', 'Summer Walker']         0.619
# 101653        0.5380            ['Kygo', 'Oh Wonder']         0.514
# 101654        0.0714    ['Cash Cash', 'Andy Grammer']         0.646
# 101655        0.1090               ['Ingrid Andress']         0.512
#
#         duration_ms  energy  explicit  instrumentalness  key  liveness  \
# 101648       167845   0.702         1           0.00000    7    0.1200
# 101649       194576   0.719         1           0.00000    0    0.0839
# 101653       180700   0.539         0           0.00233    7    0.1080
# 101654       167308   0.761         0           0.00000    1    0.2220
# 101655       214787   0.428         0           0.00000    0    0.1050
#
#         loudness  mode                                  name  popularity  \
# 101648    -6.255     0  Letter To Nipsey (feat. Roddy Ricch)          66
# 101649    -4.111     1       Back Home (feat. Summer Walker)          69
# 101653    -9.332     1                      How Would I Know          70
# 101654    -2.557     1                           I Found You          70
# 101655    -7.387     1                 More Hearts Than Mine          65
#
#        release_date  speechiness    tempo  valence  year  \
# 101648   2020-01-27       0.2880   91.885    0.338  2020
# 101649   2020-04-29       0.1570   86.036    0.351  2020
# 101653   2020-05-29       0.1050  123.700    0.153  2020
# 101654   2020-02-28       0.0385  129.916    0.472  2020
# 101655   2020-03-27       0.0271   80.588    0.366  2020
#
#                       track_id               artist_id  \
# 101648  0j2CNrgtalXRGIvHMO2vzh  20sxb77xiYeusSH8cVdatc
# 101649  5QZ11AHm7xiytOGXGlxQi5  2iojnBLj0qIMiKPvVhLnsH
# 101653  52eycxprLhK3lPcRLbQiVk  23fqKkggKUBHNkbKtXEls4
# 101654  3wYOGJYD31sLRmBgCvWxa4  1LOB7jTeEV14pHai6EXSzF
# 101655  60RFlt48hm0l4Fu0JoccOl  0jPnVIasXzBYjrlpO5irii
#
#                                                     genre  is_pop
# 101648  [hip hop, philly rap, pop rap, rap, southern h...    True
# 101649          [dance pop, pop, r&b, urban contemporary]    True
# 101653                         [edm, pop, tropical house]    True
# 101654  [big room, dance pop, edm, electro house, elec...    True
# 101655                [contemporary country, country pop]    True

# %%
# export to csv
pop_df.to_csv('data/pop_music.csv')

# %%
# export to csv
df_final.to_csv('data/music_with_genres.csv')
